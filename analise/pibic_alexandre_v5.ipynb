# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from openpyxl import load_workbook
import plotly.express as px

# %%
display(forks)
# Out:
#                                                fork_url  \
# 0     https://github.com/307509256/jetson-cloudnativ...
# 1     https://github.com/AnbuKumar-maker/jetson-clou...
# 2     https://github.com/andrewcheny/jetson-cloudnat...
# 3     https://github.com/bblwg2020/jetson-cloudnativ...
# 4     https://github.com/bobby20180331/jetson-cloudn...
# ...                                                 ...
# 3928          https://github.com/zhuzhe1983/johnny-five
# 3929              https://github.com/Ziyad2/johnny-five
# 3930           https://github.com/zmorgan87/johnny-five
# 3931               https://github.com/zomie/johnny-five
# 3932       https://github.com/ZulfiqarAkram/johnny-five
#
#                                       repo_id  \
# 0     NVIDIA-AI-IOT/jetson-cloudnative-demo\n
# 1     NVIDIA-AI-IOT/jetson-cloudnative-demo\n
# 2     NVIDIA-AI-IOT/jetson-cloudnative-demo\n
# 3     NVIDIA-AI-IOT/jetson-cloudnative-demo\n
# 4     NVIDIA-AI-IOT/jetson-cloudnative-demo\n
# ...                                       ...
# 3928                   rwaldron/johnny-five\n
# 3929                   rwaldron/johnny-five\n
# 3930                   rwaldron/johnny-five\n
# 3931                   rwaldron/johnny-five\n
# 3932                   rwaldron/johnny-five\n
#
#                                                repo_url last_update  \
# 0     https://github.com/NVIDIA-AI-IOT/jetson-cloudn...  2020-10-15
# 1     https://github.com/NVIDIA-AI-IOT/jetson-cloudn...  2020-10-15
# 2     https://github.com/NVIDIA-AI-IOT/jetson-cloudn...  2020-10-15
# 3     https://github.com/NVIDIA-AI-IOT/jetson-cloudn...  2020-10-15
# 4     https://github.com/NVIDIA-AI-IOT/jetson-cloudn...  2020-10-15
# ...                                                 ...         ...
# 3928          https://github.com/rwaldron/johnny-five\n  2016-12-14
# 3929          https://github.com/rwaldron/johnny-five\n  2016-12-14
# 3930          https://github.com/rwaldron/johnny-five\n  2016-12-14
# 3931          https://github.com/rwaldron/johnny-five\n  2016-12-14
# 3932          https://github.com/rwaldron/johnny-five\n  2016-12-14
#
#             developer                                 url_developer  \
# 0           307509256        https://api.github.com/users/307509256
# 1     AnbuKumar-maker  https://api.github.com/users/AnbuKumar-maker
# 2         andrewcheny      https://api.github.com/users/andrewcheny
# 3           bblwg2020        https://api.github.com/users/bblwg2020
# 4       bobby20180331    https://api.github.com/users/bobby20180331
# ...               ...                                           ...
# 3928       zhuzhe1983                                           NaN
# 3929           Ziyad2                                           NaN
# 3930        zmorgan87                                           NaN
# 3931            zomie                                           NaN
# 3932    ZulfiqarAkram                                           NaN
#
#      fork_update                                         commit_msg  \
# 0     2020-10-15  This branch is up to date with NVIDIA-AI-IOT/j...
# 1     2020-05-20  This branch is 2 commits behind NVIDIA-AI-IOT:...
# 2     2020-10-15  This branch is up to date with NVIDIA-AI-IOT/j...
# 3     2020-10-15  This branch is up to date with NVIDIA-AI-IOT/j...
# 4     2020-10-15  This branch is up to date with NVIDIA-AI-IOT/j...
# ...          ...                                                ...
# 3928  2018-11-26   This branch is 137 commits behind rwaldron:main.
# 3929  2018-06-10   This branch is 150 commits behind rwaldron:main.
# 3930  2015-10-22  This branch is 1108 commits behind rwaldron:main.
# 3931  2012-06-30  This branch is 3121 commits behind rwaldron:main.
# 3932  2015-12-19   This branch is 973 commits behind rwaldron:main.
#
#       update_status
# 0        ATUALIZADO
# 1     DESATUALIZADO
# 2        ATUALIZADO
# 3        ATUALIZADO
# 4        ATUALIZADO
# ...             ...
# 3928  DESATUALIZADO
# 3929  DESATUALIZADO
# 3930  DESATUALIZADO
# 3931  DESATUALIZADO
# 3932  DESATUALIZADO
#
# [3933 rows x 9 columns]
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_5157697155301644934 = autoviz.get_df('df_5157697155301644934')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_5157697155301644934, *['update_status'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_857684328873896012 = autoviz.get_df('df_857684328873896012')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_857684328873896012, *['last_update', 'count()', 'update_status'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2355243953223431849 = autoviz.get_df('df_2355243953223431849')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_2355243953223431849, *['fork_update', 'count()', 'update_status'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6318533897185355540 = autoviz.get_df('df_6318533897185355540')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_6318533897185355540, *['index'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_3123393558949498701 = autoviz.get_df('df_3123393558949498701')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_3123393558949498701, *['index'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_4606366373587888629 = autoviz.get_df('df_4606366373587888629')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_4606366373587888629, *['update_status'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6103907923929818142 = autoviz.get_df('df_6103907923929818142')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_6103907923929818142, *['index', 'update_status'], **{'inner': 'box'})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_5067005495767383850 = autoviz.get_df('df_5067005495767383850')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_5067005495767383850, *['last_update', 'count()', 'update_status'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2271599737017467201 = autoviz.get_df('df_2271599737017467201')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_2271599737017467201, *['fork_update', 'count()', 'update_status'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_530274431233947891 = autoviz.get_df('df_530274431233947891')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_530274431233947891, *['index', 'count()', 'update_status'], **{})
# chart

# %%
from pickle import FALSE
from google.colab import autoviz
df_4606366373587888629 = autoviz.get_df('df_4606366373587888629')

def categorical_histogram(df, colname, figsize=(5, 4), mpl_palette_name='Dark2'):
    from matplotlib import pyplot as plt
    import seaborn as sns
    _, ax = plt.subplots(figsize=figsize)
    bars = df[colname].value_counts()
    labels = [f'{value:.2f}%' for value in 100 * bars / bars.sum()]
    plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
    plt.title(colname)
    ax.spines[['top', 'right']].set_visible(False)
    plt.yticks(bars.index, labels)
    plt.legend(['ATUALIZADO'], loc='upper center')

    plt.legend(['DESATUALIZADO'], loc='lower right')
    return autoviz.MplChart.from_current_mpl_state()

chart = categorical_histogram(df_4606366373587888629, 'update_status')
chart
# Out:
# <img src="...">
#         <script></script>

# %%
import numpy as np
from google.colab import autoviz

df_2355243953223431849 = autoviz.get_df('df_2355243953223431849')

def time_series_bubble(df, timelike_colname, value_colname, size_colname, series_colname, figsize=(8, 4), mpl_palette_name='Dark2'):
    from matplotlib import pyplot as plt
    import seaborn as sns
    palette = list(sns.palettes.mpl_palette(mpl_palette_name))

    def _plot_series(series, series_name, series_index=0):
        xs = series[timelike_colname]
        ys = series[value_colname]
        sizes = series[size_colname]
        plt.scatter(xs, ys, s=sizes*5, label=series_name, color=palette[series_index % len(palette)])

    fig, ax = plt.subplots(figsize=figsize, constrained_layout=True)
    df = df.sort_values(timelike_colname, ascending=True)
    if series_colname:
        for i, (series_name, series) in enumerate(df.groupby(series_colname)):
            _plot_series(series, series_name, i)
        fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
    else:
        _plot_series(df, '')
    sns.despine(fig=fig, ax=ax)
    plt.xlabel(timelike_colname)
    plt.ylabel(value_colname)
    return autoviz.MplChart.from_current_mpl_state()

chart = time_series_bubble(df_2355243953223431849, 'fork_update', 'count()', 'update_status', figsize=(8, 4), mpl_palette_name='Dark2')
chart
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-ec2aa39cbecd> in <cell line: 30>()
#      28     return autoviz.MplChart.from_current_mpl_state()
#      29
# ---> 30 chart = time_series_bubble(df_2355243953223431849, 'fork_update', 'count()', 'update_status', figsize=(8, 4), mpl_palette_name='Dark2')
#      31 chart
#      32
#
# TypeError: time_series_bubble() missing 1 required positional argument: 'series_colname'

# %%
import numpy as np
from google.colab import autoviz
df_2355243953223431849 = autoviz.get_df('df_2355243953223431849')

def time_series_bubble(df, timelike_colname, value_colname, series_colname, figsize=(7,4), mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette(mpl_palette_name))
  def _plot_series(series, series_name, series_index=0):
    if value_colname == 'count()':
      counted = (series[timelike_colname]
                 .value_counts()
                 .reset_index(name='counts')
                 .rename({'index': timelike_colname}, axis=1)
                 .sort_values(timelike_colname, ascending=True))
      xs = counted[timelike_colname]
      ys = counted['counts']
    else:
      xs = series[timelike_colname]
      ys = series[value_colname]
    sizes = ys * 12
    plt.scatter(xs, ys, s=sizes, label=series_name, color=palette[series_index % len(palette)])

  fig, ax = plt.subplots(figsize=figsize, layout='constrained')
  df = df.sort_values(timelike_colname, ascending=True)
  df = df[df['fork_update'] < '2022']
  if series_colname:
    for i, (series_name, series) in enumerate(df.groupby(series_colname)):
      _plot_series(series, series_name, i)
    fig.legend(title=series_colname, bbox_to_anchor=(5, 3), loc='upper left')
  else:
    _plot_series(df, '')
  sns.despine(fig=fig, ax=ax)
  plt.xlabel(timelike_colname)
  plt.ylabel(value_colname)
  return autoviz.MplChart.from_current_mpl_state()

chart = time_series_bubble(df_2355243953223431849, *['fork_update', 'count()', None], **{})
chart
# Out:
# <img src="...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-125-2e10ece13f93> in <cell line: 3>()
#       1 import plotly.express as px
#       2
# ----> 3 fig = px.scatter(df_2355243953223431849.query("fork_update < '2022-12-31'"), x="fork_update", y="count()", size="count()", color="fork_update")
#       4 fig.show()
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_chart_types.py in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_options, trendline_color_override, trendline_scope, log_x, log_y, range_x, range_y, render_mode, title, template, width, height)
#      64     mark in 2D space.
#      65     """
# ---> 66     return make_figure(args=locals(), constructor=go.Scatter)
#      67
#      68
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    1989     apply_default_cascade(args)
#    1990
# -> 1991     args = build_dataframe(args, constructor)
#    1992     if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1993         args = process_dataframe_hierarchy(args)
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in build_dataframe(args, constructor)
#    1404     # now that things have been prepped, we do the systematic rewriting of `args`
#    1405
# -> 1406     df_output, wide_id_vars = process_args_into_dataframe(
#    1407         args, wide_mode, var_name, value_name
#    1408     )
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1206                         if argument == "index":
#    1207                             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1208                         raise ValueError(err_msg)
#    1209                 elif length and len(df_input[argument]) != length:
#    1210                     raise ValueError(
#
# ValueError: Value of 'y' is not the name of a column in 'data_frame'. Expected one of ['fork_url', 'repo_id', 'repo_url', 'last_update', 'developer', 'url_developer', 'fork_update', 'commit_msg', 'update_status'] but received: count()

# %%
import numpy as np
from google.colab import autoviz
df_1446991054711069997 = autoviz.get_df('df_1446991054711069997')

def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
  from matplotlib import pyplot as plt
  plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
  for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
    ax = plt.subplot(1, len(colname_pairs), plot_i)
    ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
    plt.xlabel(x_colname)
    plt.ylabel(y_colname)
    ax.spines[['top', 'right',]].set_visible(False)
  plt.tight_layout()
  return autoviz.MplChart.from_current_mpl_state()

chart = scatter_plots(df_1446991054711069997, *[[['index', 'lifeExp'], ['lifeExp', 'pop'], ['pop', 'gdpPercap'], ['gdpPercap', 'iso_num']]], **{})
chart

# %%
forks = px.data.gapminder()

fig = px.scatter(forks.query("atualizacao_forks"), x="gdpPercap", y="lifeExp",
	         size="pop", color="continent",
                 hover_name="country", log_x=True, size_max=60)
fig.show()

# %%
db =pd.read_excel("forks.xlsx")

# %%
forks = pd.read_excel("fork.xlsx")

# %%
forks.describe
# Out:
# <bound method NDFrame.describe of                                                fork_url  \
# 0     https://github.com/307509256/jetson-cloudnativ...
# 1     https://github.com/AnbuKumar-maker/jetson-clou...
# 2     https://github.com/andrewcheny/jetson-cloudnat...
# 3     https://github.com/bblwg2020/jetson-cloudnativ...
# 4     https://github.com/bobby20180331/jetson-cloudn...
# ...                                                 ...
# 3928          https://github.com/zhuzhe1983/johnny-five
# 3929              https://github.com/Ziyad2/johnny-five
# 3930           https://github.com/zmorgan87/johnny-five
# 3931               https://github.com/zomie/johnny-five
# 3932       https://github.com/ZulfiqarAkram/johnny-five
#
#                                       repo_id  \
# 0     NVIDIA-AI-IOT/jetson-cloudnative-demo\n
# 1     NVIDIA-AI-IOT/jetson-cloudnative-demo\n
# 2     NVIDIA-AI-IOT/jetson-cloudnative-demo\n
# 3     NVIDIA-AI-IOT/jetson-cloudnative-demo\n
# 4     NVIDIA-AI-IOT/jetson-cloudnative-demo\n
# ...                                       ...
# 3928                   rwaldron/johnny-five\n
# 3929                   rwaldron/johnny-five\n
# 3930                   rwaldron/johnny-five\n
# 3931                   rwaldron/johnny-five\n
# 3932                   rwaldron/johnny-five\n
#
#                                                repo_url last_update  \
# 0     https://github.com/NVIDIA-AI-IOT/jetson-cloudn...  2020-10-15
# 1     https://github.com/NVIDIA-AI-IOT/jetson-cloudn...  2020-10-15
# 2     https://github.com/NVIDIA-AI-IOT/jetson-cloudn...  2020-10-15
# 3     https://github.com/NVIDIA-AI-IOT/jetson-cloudn...  2020-10-15
# 4     https://github.com/NVIDIA-AI-IOT/jetson-cloudn...  2020-10-15
# ...                                                 ...         ...
# 3928          https://github.com/rwaldron/johnny-five\n  2016-12-14
# 3929          https://github.com/rwaldron/johnny-five\n  2016-12-14
# 3930          https://github.com/rwaldron/johnny-five\n  2016-12-14
# 3931          https://github.com/rwaldron/johnny-five\n  2016-12-14
# 3932          https://github.com/rwaldron/johnny-five\n  2016-12-14
#
#             developer                                 url_developer  \
# 0           307509256        https://api.github.com/users/307509256
# 1     AnbuKumar-maker  https://api.github.com/users/AnbuKumar-maker
# 2         andrewcheny      https://api.github.com/users/andrewcheny
# 3           bblwg2020        https://api.github.com/users/bblwg2020
# 4       bobby20180331    https://api.github.com/users/bobby20180331
# ...               ...                                           ...
# 3928       zhuzhe1983                                           NaN
# 3929           Ziyad2                                           NaN
# 3930        zmorgan87                                           NaN
# 3931            zomie                                           NaN
# 3932    ZulfiqarAkram                                           NaN
#
#      fork_update                                         commit_msg  \
# 0     2020-10-15  This branch is up to date with NVIDIA-AI-IOT/j...
# 1     2020-05-20  This branch is 2 commits behind NVIDIA-AI-IOT:...
# 2     2020-10-15  This branch is up to date with NVIDIA-AI-IOT/j...
# 3     2020-10-15  This branch is up to date with NVIDIA-AI-IOT/j...
# 4     2020-10-15  This branch is up to date with NVIDIA-AI-IOT/j...
# ...          ...                                                ...
# 3928  2018-11-26   This branch is 137 commits behind rwaldron:main.
# 3929  2018-06-10   This branch is 150 commits behind rwaldron:main.
# 3930  2015-10-22  This branch is 1108 commits behind rwaldron:main.
# 3931  2012-06-30  This branch is 3121 commits behind rwaldron:main.
# 3932  2015-12-19   This branch is 973 commits behind rwaldron:main.
#
#       update_status
# 0        ATUALIZADO
# 1     DESATUALIZADO
# 2        ATUALIZADO
# 3        ATUALIZADO
# 4        ATUALIZADO
# ...             ...
# 3928  DESATUALIZADO
# 3929  DESATUALIZADO
# 3930  DESATUALIZADO
# 3931  DESATUALIZADO
# 3932  DESATUALIZADO
#
# [3933 rows x 9 columns]>

# %%
db =pd.read_excel("forks.xlsx", sheet_name=fork)
display(forks)

# %%
import numpy as np
from google.colab import autoviz
df_1408804363314599985 = autoviz.get_df('df_1408804363314599985')

def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  _, ax = plt.subplots(figsize=figsize)
  bars = df[colname].value_counts()
  plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
  plt.title(colname)
  ax.spines[['top', 'right',]].set_visible(False)
  return autoviz.MplChart.from_current_mpl_state()

chart = categorical_histogram(df_1408804363314599985, *['update_status'], **{})
chart
# Out:
# <img src="...">
#         <script></script>

# %%
import numpy as np
from google.colab import autoviz
df_1408804363314599985 = autoviz.get_df('df_1408804363314599985')

def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  _, ax = plt.subplots(figsize=figsize)
  bars = df[colname].value_counts()
  for bar, value in zip(bars.index, bars.values):
    percentage = round(100 * value / len(df), 2)
    label = f'{value} ({percentage}%)'
    plt.annotate(label, (bar, value), ha='center', va='bottom')
  plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
  plt.title(colname)
  ax.spines[['top', 'right',]].set_visible(False)
  return autoviz.MplChart.from_current_mpl_state()

chart = categorical_histogram(df_1408804363314599985, *['update_status'], **{})
chart

# %%
import numpy as np
from google.colab import autoviz
df_1579261487550098238 = autoviz.get_df('df_1579261487550098238')

def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette(mpl_palette_name))
  def _plot_series(series, series_name, series_index=0):
    if value_colname == 'count()':
      counted = (series[timelike_colname]
                 .value_counts()
                 .reset_index(name='counts')
                 .rename({'index': timelike_colname}, axis=1)
                 .sort_values(timelike_colname, ascending=True))
      xs = counted[timelike_colname]
      ys = counted['counts']
    else:
      xs = series[timelike_colname]
      ys = series[value_colname]
    plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)], linewidth=2)

  fig, ax = plt.subplots(figsize=(10, 5), layout='constrained')
  df = df.sort_values(timelike_colname, ascending=True)
  if series_colname:
    for i, (series_name, series) in enumerate(df.groupby(series_colname)):
      _plot_series(series, series_name, i)
    fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
  else:
    _plot_series(df, '')
  sns.despine(fig=fig, ax=ax)
  plt.xlabel(timelike_colname)
  plt.ylabel(value_colname)
  return autoviz.MplChart.from_current_mpl_state()

chart = time_series_multiline(df_1579261487550098238, *['last_update', 'count()', None], **{})
chart
# Out:
# <img src="...

# %%
import numpy as np
from google.colab import autoviz
df_1579261487550098238 = autoviz.get_df('df_1579261487550098238')

def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette(mpl_palette_name))
  def _plot_series(series, series_name, series_index=0):
    if value_colname == 'count()':
      counted = (series[timelike_colname]
                 .value_counts()
                 .reset_index(name='counts')
                 .rename({'index': timelike_colname}, axis=1)
                 .sort_values(timelike_colname, ascending=True))
      xs = counted[timelike_colname]
      ys = counted['counts']
    else:
      xs = series[timelike_colname]
      ys = series[value_colname]
    plt.scatter(xs, ys, s=ys*5)

  fig, ax = plt.subplots(figsize=(8, 4), layout='constrained')
  df = df.sort_values(timelike_colname, ascending=True)
  if series_colname:
    for i, (series_name, series) in enumerate(df.groupby(series_colname)):
      _plot_series(series, series_name, i)
    fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
  else:
    _plot_series(df, '')
  sns.despine(fig=fig, ax=ax)
  plt.xlabel(timelike_colname)
  plt.ylabel(value_colname)
  return autoviz.MplChart.from_current_mpl_state()

chart = time_series_multiline(df_1579261487550098238, *['last_update', 'count()', None], **{})
chart
# Out:
# <img src="...
